# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import pandas as pd
import numpy as np

nba_stats = pd.read_csv('../downloads/nbastats2018-2019 - nbastats2018-2019.csv', sep = ',')

average_age = nba_stats['Age'].mean()
average_age
# Out:
# 25.900191938579656

# %% [markdown]
# # What player scored the most points?

# %%
sorted_points = nba_stats.sort_values('Points', ascending=False)
sorted_points.head()
# Out:
#                       Name  Height  Weight                   Team  Age  \
# 202           James Harden      77     220        Houston Rockets   29
# 179            Paul George      81     220  Oklahoma City Thunder   28
# 15   Giannis Antetokounmpo      83     242        Milwaukee Bucks   24
# 151            Joel Embiid      84     250     Philadelphia 76ers   24
# 253           LeBron James      80     250     Los Angeles Lakers   34
#
#        Salary  Points  Blocks  Steals  Assists  ...    MP   G   PER   OWS  \
# 202  30431854    36.1     0.7     2.0      7.5  ...  36.8  78  30.6  11.4
# 179  30560700    28.0     0.4     2.2      4.1  ...  36.9  77  23.3   7.0
# 15   24157304    27.7     1.5     1.3      5.9  ...  32.8  72  30.9   8.9
# 151  25467250    27.5     1.9     0.7      3.7  ...  33.7  64  26.1   4.9
# 253  35654150    27.4     0.6     1.3      8.3  ...  35.2  55  25.6   4.7
#
#      DWS    WS   WS48   USG   BPM  VORP
# 202  3.8  15.2  0.254  40.5  11.7   9.9
# ...

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
sorted_blocks = nba_stats.sort_values('Blocks', ascending=False)
sorted_blocks.head()
#There are no postitions in the file
# Out:
#                   Name  Height  Weight                  Team  Age    Salary  \
# 476       Myles Turner      83     250        Indiana Pacers   22   3410284
# 123      Anthony Davis      82     253  New Orleans Pelicans   25  25434263
# 419  Mitchell Robinson      85     240       New York Knicks   20   1485440
# 183        Rudy Gobert      85     245             Utah Jazz   26  23241573
# 303        Brook Lopez      84     270       Milwaukee Bucks   30   3382000
#
#      Points  Blocks  Steals  Assists  ...   G   PER  OWS  DWS    WS   WS48  \
# 476    13.3     2.7     0.8      1.6  ...  74  18.0  1.9  4.4   6.3  0.144
# 123    25.9     2.4     1.6      3.9  ...  56  30.3  6.4  3.1   9.5  0.247
# 419     7.3     2.4     0.8      0.6  ...  66  22.0  4.0  2.2   6.1  0.217
# 183    15.9     2.3     0.8      2.0  ...  81  24.6  8.7  5.7  14.4  0.268
# 303    12.5     2.2     0.6      1.2  ...  81  14.6  2.3  4.3   6.7  0.138
#
#       USG  BPM  VORP  total_minutes_played
# ...

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
# There is no win percentage column

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
sorted_threes = nba_stats.sort_values('FG3%', ascending=False)
sorted_threes.head()
# Out:
#               Name  Height  Weight                Team  Age  Salary  Points  \
# 312  Scott Machado      73     205  Los Angeles Lakers   28   47371     2.5
# 439  Jordan Sibert      76     187       Atlanta Hawks   26   47371     3.0
# 147   Trevon Duval      74     189                 NaN   20       -     1.7
# 352  Eric Moreland      82     238        Phoenix Suns   27  239035     1.4
# 95    Troy Caupain      76     210                 NaN   23       -     2.5
#
#      Blocks  Steals  Assists  ...   MP  G   PER  OWS  DWS   WS   WS48   USG  \
# 312     0.0     0.3      0.8  ...  4.8  4  22.2  0.1  0.0  0.1  0.281  14.0
# 439     0.0     0.0      0.0  ...  4.0  1  29.7  0.0  0.0  0.0  0.183  10.2
# 147     0.0     0.0      0.7  ...  2.0  3  38.3  0.1  0.0  0.1  0.537  20.9
# 352     0.2     0.2      0.8  ...  8.6  5   6.7 -0.1  0.1  0.0  0.032  12.0
# 95      0.0     0.3      1.0  ...  4.0  4  30.7  0.1  0.0  0.1  0.347  21.8
#
#      BPM  VORP
# 312 -4.4   0.0
# 439  6.3   0.0
# ...

# %% [markdown]
# # Who played the most minutes during the season

# %%
sorted_threes = nba_stats.sort_values('FG3%', ascending=False)
sorted_threes.head()

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nba_stats['total_minutes_played'] = nba_stats['MP'] * nba_stats['G']
nba_minutes_played = nba_stats.sort_values('total_minutes_played', ascending=False)
nba_minutes_played.head()
# Out:
#               Name  Height  Weight                   Team  Age    Salary  \
# 37    Bradley Beal      77     207     Washington Wizards   25  25434263
# 202   James Harden      77     220        Houston Rockets   29  30431854
# 486   Kemba Walker      73     184      Charlotte Hornets   28  12000000
# 208  Tobias Harris      81     235     Philadelphia 76ers   26  14800000
# 179    Paul George      81     220  Oklahoma City Thunder   28  30560700
#
#      Points  Blocks  Steals  Assists  ...   G   PER   OWS  DWS    WS   WS48  \
# 37     25.6     0.7     1.5      5.5  ...  82  20.8   5.9  1.7   7.6  0.120
# 202    36.1     0.7     2.0      7.5  ...  78  30.6  11.4  3.8  15.2  0.254
# 486    25.6     0.4     1.2      5.9  ...  82  21.7   5.5  1.9   7.4  0.123
# 208    20.0     0.5     0.6      2.8  ...  82  17.2   4.5  2.6   7.1  0.120
# 179    28.0     0.4     2.2      4.1  ...  77  23.3   7.0  4.9  11.9  0.201
#
#       USG   BPM  VORP  total_minutes_played
# ...

# %% [markdown]
# # What team had the youngest roster?

# %%
nba_youngest_team = nba_stats.groupby('Team')['Age'].mean().reset_index()
nba_youngest_team_sorted = nba_youngest_team.sort_values('Age', ascending=True)
nba_youngest_team_sorted.head()
# Out:
#                 Team        Age
# 4      Chicago Bulls  24.312500
# 25  Sacramento Kings  24.400000
# 21     Orlando Magic  24.533333
# 19   New York Knicks  24.625000
# 23      Phoenix Suns  24.761905

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
nba_highest_paid = nba_stats.sort_values('Salary', ascending=False)
nba_highest_paid.head()
# Out:
#                     Name  Height  Weight                 Team  Age   Salary  \
# 255         John Jenkins      76     215   Washington Wizards   27    99290
# 188      Devonte' Graham      74     185    Charlotte Hornets   23   988464
# 402        Dwight Powell      83     240     Dallas Mavericks   27  9631250
# 129  Matthew Dellavedova      76     200  Cleveland Cavaliers   28  9607500
# 157           Dante Exum      78     190            Utah Jazz   23  9600000
#
#      Points  Blocks  Steals  Assists  ...   G   PER  OWS  DWS   WS   WS48  \
# 255     4.7     0.1     0.0      0.8  ...  26   9.7  0.2  0.0  0.2  0.031
# 188     4.7     0.0     0.5      2.6  ...  46  10.3  0.2  0.3  0.5  0.035
# 402    10.6     0.6     0.6      1.5  ...  77  20.4  5.6  1.9  7.5  0.215
# 129     5.9     0.0     0.3      3.8  ...  48  11.1  0.5  0.0  0.5  0.028
# 157     6.9     0.1     0.3      2.6  ...  42  11.2  0.2  0.7  1.0  0.069
#
#       USG  BPM  VORP  total_minutes_played
# ...

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nba_bad_at_fts = nba_stats.sort_values('FT%')
nba_bad_at_fts.head()
# Out:
#                    Name  Height  Weight                   Team  Age   Salary  \
# 268      Terrence Jones      81     252        Houston Rockets   27   198580
# 221   Haywood Highsmith      79     220                    NaN   22        -
# 356  Donatas Motiejunas      84     222      San Antonio Spurs   28    59820
# 502       C.J. Williams      77     226                    NaN   28        -
# 154         Jacob Evans      78     210  Golden State Warriors   21  1644240
#
#      Points  Blocks  Steals  Assists  ...   G   PER  OWS  DWS   WS   WS48  \
# 268     1.0     0.0     0.0      0.0  ...   2 -15.8 -0.1  0.0 -0.1 -0.661
# 221     1.8     0.0     0.2      0.4  ...   5   4.5  0.0  0.0  0.0 -0.023
# 356     2.0     0.3     0.0      0.3  ...   3  -0.5 -0.1  0.0 -0.1 -0.246
# 502     2.6     0.0     0.4      0.8  ...  15   8.8  0.1  0.1  0.1  0.042
# 154     1.3     0.1     0.2      0.8  ...  30   3.5 -0.3  0.2 -0.1 -0.030
#
#       USG   BPM  VORP  total_minutes_played
# ...
